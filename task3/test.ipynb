# %%
import geopandas

import numpy as np
import rtree
import pygeos
from shapely.geometry import Polygon
import json
# Out:
# /home/dlichman/miniconda3/envs/vpirod/lib/python3.8/site-packages/geopandas/_compat.py:84: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.8.1-CAPI-1.13.3). Conversions between both will be slow.
#   warnings.warn(

# %%
file = geopandas.read_file('admin1-us.geojson')

# %%
file = file.drop(index=[3,50])

# %%
file1 = geopandas.read_file('part_0.geojson')
file2 = geopandas.read_file('part_1.geojson')
file3 = geopandas.read_file('part_2.geojson')
file4 = geopandas.read_file('part_3.geojson')
file5 = geopandas.read_file('part_4.geojson')
file6 = geopandas.read_file('part_5.geojson')
file7 = geopandas.read_file('part_6.geojson')
file8 = geopandas.read_file('part_7.geojson')
ax = file.plot(figsize=(20, 15))
file1.plot(color='yellow',alpha=0.55,ax=ax)
file2.plot(color='blue',alpha=0.55,ax=ax)
file3.plot(color='green',alpha=0.55,ax=ax)
file4.plot(color='red',alpha=0.55,ax=ax)
file5.plot(color='coral',alpha=0.55,ax=ax)
file6.plot(color='lime',alpha=0.55,ax=ax)
file7.plot(color='pink',alpha=0.55,ax=ax)
file8.plot(color='indigo',alpha=0.55,ax=ax)
# Out:
# <AxesSubplot:>

# %%
file1 = geopandas.read_file('part_0.geojson')
file2 = geopandas.read_file('part_1.geojson')
file3 = geopandas.read_file('part_2.geojson')
file4 = geopandas.read_file('part_3.geojson')
file5 = geopandas.read_file('part_4.geojson')
file6 = geopandas.read_file('part_5.geojson')
file7 = geopandas.read_file('part_6.geojson')
file8 = geopandas.read_file('part_7.geojson')
file9 = geopandas.read_file('part_8.geojson')
file10 = geopandas.read_file('part_9.geojson')
file11 = geopandas.read_file('part_10.geojson')
file12 = geopandas.read_file('part_11.geojson')
file13 = geopandas.read_file('part_12.geojson')
file14 = geopandas.read_file('part_13.geojson')
file15 = geopandas.read_file('part_14.geojson')
file16 = geopandas.read_file('part_15.geojson')

# %%
file1 = geopandas.read_file('part_0.geojson')
file2 = geopandas.read_file('part_1.geojson')
file3 = geopandas.read_file('part_2.geojson')
file4 = geopandas.read_file('part_3.geojson')
ax = file.plot(figsize=(20, 15))
file1.plot(color='yellow',alpha=0.5,ax=ax)
file2.plot(color='blue',alpha=0.5,ax=ax)
file3.plot(color='green',alpha=0.5,ax=ax)
file4.plot(color='red',alpha=0.5,ax=ax)
# Out:
# <AxesSubplot:>

# %%
ax = file.plot(figsize=(20, 15))
file1.plot(color='yellow',alpha=0.55,ax=ax)
file2.plot(color='blue',alpha=0.55,ax=ax)
file3.plot(color='green',alpha=0.55,ax=ax)
file4.plot(color='red',alpha=0.55,ax=ax)
file5.plot(color='coral',alpha=0.55,ax=ax)
file6.plot(color='lime',alpha=0.55,ax=ax)
file7.plot(color='pink',alpha=0.55,ax=ax)
file8.plot(color='aqua',alpha=0.55,ax=ax)
file9.plot(color='indigo',alpha=0.55,ax=ax)
file10.plot(color='gold',alpha=0.55,ax=ax)
file11.plot(color='violet',alpha=0.55,ax=ax)
file12.plot(color='wheat',alpha=0.55,ax=ax)
file13.plot(color='silver',alpha=0.55,ax=ax)
file14.plot(color='salmon',alpha=0.55,ax=ax)
file15.plot(color='orange',alpha=0.55,ax=ax)
file16.plot(color='navy',alpha=0.55,ax=ax)
# Out:
# /home/dlichman/miniconda3/envs/vpirod/lib/python3.8/site-packages/geopandas/plotting.py:604: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   warnings.warn(
# /home/dlichman/miniconda3/envs/vpirod/lib/python3.8/site-packages/geopandas/plotting.py:604: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   warnings.warn(
# <AxesSubplot:>

# %%
file1 = geopandas.read_file('part_0.geojson')
file2 = geopandas.read_file('part_1.geojson')
ax = file.plot(figsize=(20, 15))
file1.plot(color='salmon',alpha=0.55,ax=ax)
file2.plot(color='blue',alpha=0.55,ax=ax)
# Out:
# <AxesSubplot:>

# %%
file1 = geopandas.read_file('part_0.geojson')
file2 = geopandas.read_file('part_1.geojson')
ax = file.plot(figsize=(20, 15))
file1.plot(color='salmon',alpha=0.55,ax=ax)
file2.plot(color='blue',alpha=0.55,ax=ax)
# Out:
# <AxesSubplot:>

# %%
file1 = geopandas.read_file('part_0.geojson')
file2 = geopandas.read_file('part_1.geojson')
file3 = geopandas.read_file('part_2.geojson')
file4 = geopandas.read_file('part_3.geojson')
file5 = geopandas.read_file('part_4.geojson')
file6 = geopandas.read_file('part_5.geojson')
file7 = geopandas.read_file('part_6.geojson')
file8 = geopandas.read_file('part_7.geojson')
file9 = geopandas.read_file('part_8.geojson')
ax = file.plot(figsize=(20, 15))
file1.plot(color='yellow',alpha=0.55,ax=ax)
file2.plot(color='blue',alpha=0.55,ax=ax)
file3.plot(color='green',alpha=0.55,ax=ax)
file4.plot(color='red',alpha=0.55,ax=ax)
file5.plot(color='coral',alpha=0.55,ax=ax)
file6.plot(color='lime',alpha=0.55,ax=ax)
file7.plot(color='pink',alpha=0.55,ax=ax)
file8.plot(color='aqua',alpha=0.55,ax=ax)
file9.plot(color='indigo',alpha=0.55,ax=ax)
# Out:
# <AxesSubplot:>

# %%
file1 = geopandas.read_file('part_0.geojson')
file2 = geopandas.read_file('part_1.geojson')
file3 = geopandas.read_file('part_2.geojson')
file4 = geopandas.read_file('part_3.geojson')
file5 = geopandas.read_file('part_4.geojson')
ax = file.plot(figsize=(20, 15))
file1.plot(color='yellow',alpha=0.55,ax=ax)
file2.plot(color='blue',alpha=0.55,ax=ax)
file3.plot(color='green',alpha=0.55,ax=ax)
file4.plot(color='red',alpha=0.55,ax=ax)
file5.plot(color='coral',alpha=0.55,ax=ax)
# Out:
# <AxesSubplot:>

# %%
file1 = file.drop(index=[3,50])

# %%
file1
# Out:
#                     name                   country ISO3166-1-Alpha-3  \
# 0              Minnesota  United States of America               USA
# 1                Montana  United States of America               USA
# 2           North Dakota  United States of America               USA
# 4                  Idaho  United States of America               USA
# 5             Washington  United States of America               USA
# 6                Arizona  United States of America               USA
# 7             California  United States of America               USA
# 8               Colorado  United States of America               USA
# 9                 Nevada  United States of America               USA
# 10            New Mexico  United States of America               USA
# 11                Oregon  United States of America               USA
# 12                  Utah  United States of America               USA
# 13               Wyoming  United States of America               USA
# ...

# %%
# quadrant = geopandas.GeoSeries([Polygon([(-100,30), (-100, 40), (-90, 40), (-90, 30)])])
# df1 = geopandas.GeoDataFrame({'geometry': quadrant, 'df1':[1]})
# df1
quadrant = geopandas.GeoSeries([Polygon([(-127,25), (-127, 40), (-95, 40), (-95, 25)])])
df1 = geopandas.GeoDataFrame({'geometry': quadrant, 'df1':[1]})
df1
# Out:
#                                             geometry  df1
# 0  POLYGON ((-127.00000 25.00000, -127.00000 40.0...    1

# %%
df2 = geopandas.GeoDataFrame({'geometry': file1.iloc[21]['geometry'], 'df2':[1]})

# %%
df2 = file1

# %%
res_union = geopandas.overlay(df1, df2, how='intersection')
# Out:
# <ipython-input-39-1dd39e00100d>:1: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   res_union = geopandas.overlay(df1, df2, how='intersection')

# %%
str(res_union)
# Out:
# '   df1        name                   country ISO3166-1-Alpha-3 state_code  \\\n0    1     Arizona  United States of America               USA         AZ   \n1    1  California  United States of America               USA         CA   \n2    1    Colorado  United States of America               USA         CO   \n3    1      Nevada  United States of America               USA         NV   \n4    1  New Mexico  United States of America               USA         NM   \n5    1        Utah  United States of America               USA         UT   \n6    1      Kansas  United States of America               USA         KS   \n7    1    Missouri  United States of America               USA         MO   \n8    1    Oklahoma  United States of America               USA         OK   \n9    1       Texas  United States of America               USA         TX   \n\n         id                                           geometry  \n0  USA-3520  POLYGON ((-109.04522 36.99991, -109.04367 31.3...  \n1  U
# ...

# %%
t = res_union.to_json()

# %%
t.
# Out:
# '{"type": "FeatureCollection", "features": [{"id": "0", "type": "Feature", "properties": {"ISO3166-1-Alpha-3": "USA", "country": "United States of America", "df1": 1, "id": "USA-3520", "name": "Arizona", "state_code": "AZ"}, "geometry": {"type": "Polygon", "coordinates": [[[-109.04522477907244, 36.999912421205295], [-109.04367281021746, 31.34189913731541], [-111.02378618044753, 31.33465098726333], [-113.30501644575611, 32.03897492118551], [-114.81474341516332, 32.52527598726806], [-114.72139, 32.72083], [-114.58984758182902, 32.7162979192351], [-114.47977678104735, 32.91633738863692], [-114.6559934151627, 33.05390005139793], [-114.6914434477149, 33.20368419039579], [-114.74330074751975, 33.379874986294965], [-114.54855811242783, 33.6095250514], [-114.46918311242757, 34.067274888641464], [-114.16597164595498, 34.27258535413716], [-114.35490068241404, 34.464666652966], [-114.48453101281825, 34.653053086886075], [-114.5670841134044, 34.82821035413929], [-114.62211951379533, 34.963680121
# ...

# %%
t
# Out:
# '{"type": "FeatureCollection", "features": [{"id": "0", "type": "Feature", "properties": {"ISO3166-1-Alpha-3": "USA", "country": "United States of America", "df1": 1, "id": "USA-3520", "name": "Arizona", "state_code": "AZ"}, "geometry": {"type": "Polygon", "coordinates": [[[-109.04522477907244, 36.999912421205295], [-109.04367281021746, 31.34189913731541], [-111.02378618044753, 31.33465098726333], [-113.30501644575611, 32.03897492118551], [-114.81474341516332, 32.52527598726806], [-114.72139, 32.72083], [-114.58984758182902, 32.7162979192351], [-114.47977678104735, 32.91633738863692], [-114.6559934151627, 33.05390005139793], [-114.6914434477149, 33.20368419039579], [-114.74330074751975, 33.379874986294965], [-114.54855811242783, 33.6095250514], [-114.46918311242757, 34.067274888641464], [-114.16597164595498, 34.27258535413716], [-114.35490068241404, 34.464666652966], [-114.48453101281825, 34.653053086886075], [-114.5670841134044, 34.82821035413929], [-114.62211951379533, 34.963680121
# ...

# %%
res_union

# %%
 t
# Out:
# '{"type": "FeatureCollection", "features": [{"id": "0", "type": "Feature", "properties": {"ISO3166-1-Alpha-3": "USA", "country": "United States of America", "df1": 1, "id": "USA-3520", "name": "Arizona", "state_code": "AZ"}, "geometry": {"type": "Polygon", "coordinates": [[[-109.04522477907244, 36.999912421205295], [-109.04367281021746, 31.34189913731541], [-111.02378618044753, 31.33465098726333], [-113.30501644575611, 32.03897492118551], [-114.81474341516332, 32.52527598726806], [-114.72139, 32.72083], [-114.58984758182902, 32.7162979192351], [-114.47977678104735, 32.91633738863692], [-114.6559934151627, 33.05390005139793], [-114.6914434477149, 33.20368419039579], [-114.74330074751975, 33.379874986294965], [-114.54855811242783, 33.6095250514], [-114.46918311242757, 34.067274888641464], [-114.16597164595498, 34.27258535413716], [-114.35490068241404, 34.464666652966], [-114.48453101281825, 34.653053086886075], [-114.5670841134044, 34.82821035413929], [-114.62211951379533, 34.963680121
# ...

# %%
text_file = open("Output.geojson", "w")

text_file.write(t)

text_file.close()

# %%
df2 = geopandas.GeoDataFrame(t)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-4321604c4f63> in <module>
# ----> 1 df2 = geopandas.GeoDataFrame(t)
#       2
#
# ~/miniconda3/envs/vpirod/lib/python3.8/site-packages/geopandas/geodataframe.py in __init__(self, *args, **kwargs)
#      87         crs = kwargs.pop("crs", None)
#      88         geometry = kwargs.pop("geometry", None)
# ---> 89         super(GeoDataFrame, self).__init__(*args, **kwargs)
#      90
#      91         # need to set this before calling self['geometry'], because
#
# ~/miniconda3/envs/vpirod/lib/python3.8/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     527         else:
#     528             if index is None or columns is None:
# --> 529                 raise ValueError("DataFrame constructor not properly called!")
#     530
#     531             if not dtype:
#
# ...

# %%
type(res_union)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
res_union.to_string(string_geo)

# %%
res_union.to_file("Usa.geojson", driver='GeoJSON')

# %%
res_union = res_union.to_json()

# %%
res_union
# Out:
# '{"type": "FeatureCollection", "features": [{"id": "0", "type": "Feature", "properties": {"ISO3166-1-Alpha-3": "USA", "country": "United States of America", "df1": 1, "id": "USA-3520", "name": "Arizona", "state_code": "AZ"}, "geometry": {"type": "Polygon", "coordinates": [[[-109.04522477907244, 36.999912421205295], [-109.04367281021746, 31.34189913731541], [-111.02378618044753, 31.33465098726333], [-113.30501644575611, 32.03897492118551], [-114.81474341516332, 32.52527598726806], [-114.72139, 32.72083], [-114.58984758182902, 32.7162979192351], [-114.47977678104735, 32.91633738863692], [-114.6559934151627, 33.05390005139793], [-114.6914434477149, 33.20368419039579], [-114.74330074751975, 33.379874986294965], [-114.54855811242783, 33.6095250514], [-114.46918311242757, 34.067274888641464], [-114.16597164595498, 34.27258535413716], [-114.35490068241404, 34.464666652966], [-114.48453101281825, 34.653053086886075], [-114.5670841134044, 34.82821035413929], [-114.62211951379533, 34.963680121
# ...

# %%
type(res_union)
# Out:
# str

# %%
lol = json.loads(res_union)

# %%
file = geopandas.read_file('Output.geojson'

# %%
lol.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-9db86d5894bf> in <module>
# ----> 1 lol.plot()
#       2
#       3
#
# AttributeError: 'dict' object has no attribute 'plot'

# %%
sas = geopandas.GeoDataFrame(lol)

# %%
sas
# Out:
#                 type                                           features
# 0  FeatureCollection  {'id': '0', 'type': 'Feature', 'properties': {...
# 1  FeatureCollection  {'id': '1', 'type': 'Feature', 'properties': {...
# 2  FeatureCollection  {'id': '2', 'type': 'Feature', 'properties': {...
# 3  FeatureCollection  {'id': '3', 'type': 'Feature', 'properties': {...
# 4  FeatureCollection  {'id': '4', 'type': 'Feature', 'properties': {...
# 5  FeatureCollection  {'id': '5', 'type': 'Feature', 'properties': {...
# 6  FeatureCollection  {'id': '6', 'type': 'Feature', 'properties': {...
# 7  FeatureCollection  {'id': '7', 'type': 'Feature', 'properties': {...
# 8  FeatureCollection  {'id': '8', 'type': 'Feature', 'properties': {...
# 9  FeatureCollection  {'id': '9', 'type': 'Feature', 'properties': {...

# %%
res_union = json.dumps(res_union)

# %%
normal = json.loads(res_union)

# %%
with open('kek.json', "w") as output:
    json.dump(normal, output)

# %%
res_union = geopandas.overlay(df1, df2, how='intersection')

# %%
res_union.plot()
# Out:
# <AxesSubplot:>

# %%
ax = file1.plot(alpha=0.5, cmap='viridis',figsize=(20, 15))
res_union.plot(ax=ax)
df1.plot(ax=ax, cmap='spring',alpha = 0.1)
# Out:
# <AxesSubplot:>

# %%
file
# Out:
#   ISO3166-1-Alpha-3                   country  df1        id        name  \
# 0               USA  United States of America    1  USA-3520     Arizona
# 1               USA  United States of America    1  USA-3521  California
# 2               USA  United States of America    1  USA-3522    Colorado
# 3               USA  United States of America    1  USA-3523      Nevada
# 4               USA  United States of America    1  USA-3524  New Mexico
# 5               USA  United States of America    1  USA-3526        Utah
# 6               USA  United States of America    1  USA-3530      Kansas
# 7               USA  United States of America    1  USA-3531    Missouri
# 8               USA  United States of America    1  USA-3533    Oklahoma
# 9               USA  United States of America    1  USA-3536       Texas
#
#   state_code                                           geometry
# 0         AZ  POLYGON ((-109.04522 36.99991, -109.04367 31.3...
# ...
